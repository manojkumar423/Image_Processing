# %%
#!pip install scikit-image

# %%
from skimage import io
from skimage import feature

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


im = io.imread('E://New_folder//test2.jpeg',flatten=True)
edges = feature.canny(im)
io.imshow(edges)
io.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Read our Image
# cv2.imread()--> used to read an image

img = cv2.imread('E://New_folder//test2.jpeg',0)
# implement canny algorithm on image
edges = cv2.Canny(img,100,200)
# plot original image and edges 

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
#Real Time Edege Detection
# Capture frames from a camera

cap = cv2.VideoCapture(0)

while(1):
    # Read Frames from camera 
    ret, frame = cap.read()
    
    #convert BGR to HSV
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV_FULL)
    # Define range of red color in HSV
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    #create a HSV Color boundary
    
    mask = cv2.inRange(hsv,lower_red,upper_red)
    # bitwise AND Operation mask and original image 
    res = cv2.bitwise_and(frame,frame,mask=mask)
    cv2.imshow('Original Frame',frame)
    edges = cv2.Canny(frame,100,200)
    cv2.imshow('Edges',edges)
    k = cv2.waitKey(5) & 0xFF #press ESC key
    if k == 27:
        break

# close the window()
cap.release()
cv2.destroyAllWindows()
